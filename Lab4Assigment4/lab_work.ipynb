# %%
import math
import random

def load_tsp(filename: str) -> list:
    coords = []
    with open(filename) as f:
        for line in f:
            if line.strip() == 'NODE_COORD_SECTION':
                break
        for line in f:
            if line.strip() == 'EOF':
                break
            parts = line.split()
            x, y = float(parts[1]), float(parts[2])
            coords.append((x, y))
    return coords

# %%
def euclidean_distance(a: tuple, b: tuple) -> float:
    return math.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2)

def tour_length(tour, dist ):
    n = len(tour)
    return sum(dist[tour[i]][tour[(i + 1) % n]] for i in range(n))

# %%
def greedy_tsp(filename: str) -> tuple:
    """A solution for the tsp problem using a greedy method.
    The method consists of starting at a random node and always selecting the closest unvisited node
    

    Args:
        filename (str): _description_

    Returns:
        tuple: _description_
    """
    
    coords = load_tsp(filename)
    n = len(coords)
    start = random.randint(0,n-1)

    tour = [start]
    available = set(range(n))
    available.remove(start)
    current = start
    
    dists = [[euclidean_distance(coords[i], coords[j]) 
         for j in range(n)] 
         for i in range(n)]

    while available:
        nearest = None
        nearest_dist = float('inf')

        for node in available:
            dist = euclidean_distance(coords[current], coords[node])
            if dist < nearest_dist:
                nearest_dist = dist
                nearest = node        
        tour.append(nearest)
        available.remove(nearest)
        current = nearest

    length = tour_length(tour, dists)
    return tour, length, dists

# %%
import random
import math

def simulated_annealing_tsp(filename: str, T_max: float = 10000, T_min: float = 0.1,alpha: float = 0.999,iterations_per_temp: int = 50):

    coords = load_tsp(filename)
    n = len(coords)

    _, _, dists = greedy_tsp(filename)

    c = list(range(n))
    random.shuffle(c)
    c_length = tour_length(c, dists)

    best = c.copy()
    best_length = c_length

    T = T_max
    t = 0

    while T > T_min:

        for _ in range(iterations_per_temp):

            i = random.randint(0, n - 2)
            j = random.randint(i + 1, n - 1)
            x = c.copy()
            x[i:j+1] = x[i:j+1][::-1]
            x_length = tour_length(x, dists)
            
            delta = x_length - c_length

            if delta < 0:
                c = x
                c_length = x_length
            elif random.random() < math.exp(-delta / T):
                c = x
                c_length = x_length

            if c_length < best_length:
                best = c.copy()
                best_length = c_length

        T = alpha * T
        t+=1
        if t% 100 == 0 :
            print(f"Result at step_{t} is {best_length}")

    return best_length

# %%
simulated_annealing_tsp('../Lab3Assigment3/berlin52.tsp')
# Out:
# Result at step_100 is 24020.54001639862
# Result at step_200 is 24020.54001639862
# Result at step_300 is 23696.62069908207
# Result at step_400 is 23696.62069908207
# Result at step_500 is 23696.62069908207
# Result at step_600 is 23284.880372722902
# Result at step_700 is 22886.931428340817
# Result at step_800 is 22886.931428340817
# Result at step_900 is 22886.931428340817
# Result at step_1000 is 22886.931428340817
# Result at step_1100 is 22886.931428340817
# Result at step_1200 is 22886.931428340817
# Result at step_1300 is 22886.931428340817
# Result at step_1400 is 22886.931428340817
# Result at step_1500 is 22886.931428340817
# Result at step_1600 is 22756.113152244812
# Result at step_1700 is 22155.299938081556
# Result at step_1800 is 22155.299938081556
# Result at step_1900 is 22155.299938081556
# Result at step_2000 is 22155.299938081556
# Result at step_2100 is 19004.398544363496
# Result at step_2200 is 19004.398544363496
# Result at step_2300 is 19004.398544363496
# Result at step_2400 is 19004.398544363496
# Result at step_2500 is 19004.398544363496
# Result at step_2600 is 19004.398544363496
# Result at step_2700 is 19004.398544363496
# Result at step_2800 is 19004.398544363496
# Result at step_2900 is 19004.398544363496
# Result at step_3000 is 18861.25108348934
# Result at step_3100 is 17847.532003938155
# Result at step_3200 is 17847.532003938155
# Result at step_3300 is 17144.258418203106
# Result at step_3400 is 17144.258418203106
# Result at step_3500 is 16110.247979981536
# Result at step_3600 is 15981.59912544804
# Result at step_3700 is 15981.59912544804
# Result at step_3800 is 15081.73818964891
# Result at step_3900 is 13028.902941865805
# Result at step_4000 is 13028.902941865805
# Result at step_4100 is 12676.112834154517
# Result at step_4200 is 11847.245396984199
# Result at step_4300 is 11475.588997577435
# Result at step_4400 is 11076.49129183111
# Result at step_4500 is 11047.900268323347
# Result at step_4600 is 9846.627101218271
# Result at step_4700 is 9846.627101218271
# Result at step_4800 is 9381.007662332158
# Result at step_4900 is 9381.007662332158
# Result at step_5000 is 9148.814685972384
# Result at step_5100 is 8819.377318479268
# Result at step_5200 is 8819.377318479268
# Result at step_5300 is 8523.21678955264
# Result at step_5400 is 8523.21678955264
# Result at step_5500 is 8199.149290322059
# Result at step_5600 is 8194.251511581404
# Result at step_5700 is 7912.51235216962
# Result at step_5800 is 7860.551728654718
# Result at step_5900 is 7778.464599795104
# Result at step_6000 is 7614.6866532803715
# Result at step_6100 is 7614.6866532803715
# Result at step_6200 is 7614.6866532803715
# Result at step_6300 is 7614.6866532803715
# Result at step_6400 is 7561.222877854432
# Result at step_6500 is 7548.992710024182
# Result at step_6600 is 7548.992710024182
# Result at step_6700 is 7544.36590190409
# Result at step_6800 is 7544.36590190409
# Result at step_6900 is 7544.36590190409
# Result at step_7000 is 7544.36590190409
# Result at step_7100 is 7544.36590190409
# Result at step_7200 is 7544.36590190409
# Result at step_7300 is 7544.36590190409
# Result at step_7400 is 7544.36590190409
# Result at step_7500 is 7544.36590190409
# Result at step_7600 is 7544.36590190409
# Result at step_7700 is 7544.36590190409
# Result at step_7800 is 7544.36590190409
# Result at step_7900 is 7544.36590190409
# Result at step_8000 is 7544.36590190409
# Result at step_8100 is 7544.36590190409
# Result at step_8200 is 7544.36590190409
# Result at step_8300 is 7544.36590190409
# Result at step_8400 is 7544.36590190409
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 simulated_annealing_tsp('../Lab3Assigment3/berlin52.tsp')
#
# Cell In[24], line 26, in simulated_annealing_tsp(filename, T_max, T_min, alpha, iterations_per_temp)
#      23 for _ in range(iterations_per_temp):
#      25     i = random.randint(0, n - 2)
# ---> 26     j = random.randint(i + 1, n - 1)
#      27     x = c.copy()
#      28     x[i:j+1] = x[i:j+1][::-1]
#
# File d:\Info\AnacondaFolder\Lib\random.py:340, in Random.randint(self, a, b)
#     336 def randint(self, a, b):
#     337     """Return random integer in range [a, b], including both end points.
#     338     """
# --> 340     return self.randrange(a, b+1)
#
# File d:\Info\AnacondaFolder\Lib\random.py:305, in Random.randrange(self, start, stop, step)
#     296 """Choose a random item from range(stop) or range(start, stop[, step]).
#     297
#     298 Roughly equivalent to ``choice(range(start, stop, step))`` but
#     299 supports arbitrarily large ranges and is optimized for common cases.
#     300
#     301 """
#     303 # This code is a bit messy to make it fast for the
#     304 # common case while still doing adequate error checking.
# --> 305 istart = _index(start)
#     306 if stop is None:
#     307     # We don't check for "step != 1" because it hasn't been
#     308     # type checked and converted to an integer yet.
#     309     if step is not _ONE:
#
# KeyboardInterrupt:

# %%
simulated_annealing_tsp('../Lab3Assigment3/rw1621.tsp')
# Out:
# Result at step_100 is 1148739.4315547259
# Result at step_200 is 1147261.4961838722
# Result at step_300 is 1144863.222319994
# Result at step_400 is 1136479.9045183724
# Result at step_500 is 1134476.509293678
# Result at step_600 is 1133354.170937304
# Result at step_700 is 1128610.2388723046
# Result at step_800 is 1119540.8850674478
# Result at step_900 is 1119540.8850674478
# Result at step_1000 is 1119540.8850674478
# Result at step_1100 is 1104971.4303937394
# Result at step_1200 is 1089415.7856364627
# Result at step_1300 is 1089415.7856364627
# Result at step_1400 is 1089415.7856364627
# Result at step_1500 is 1089415.7856364627
# Result at step_1600 is 1087019.0726016017
# Result at step_1700 is 1048800.889345889
# Result at step_1800 is 1048800.889345889
# Result at step_1900 is 1048800.889345889
# Result at step_2000 is 1010262.9481853587
# Result at step_2100 is 1002769.1786395217
# Result at step_2200 is 1002769.1786395217
# Result at step_2300 is 995391.1564404394
# Result at step_2400 is 935717.807388633
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 simulated_annealing_tsp('../Lab3Assigment3/rw1621.tsp')
#
# Cell In[24], line 29, in simulated_annealing_tsp(filename, T_max, T_min, alpha, iterations_per_temp)
#      27 x = c.copy()
#      28 x[i:j+1] = x[i:j+1][::-1]
# ---> 29 x_length = tour_length(x, dists)
#      31 delta = x_length - c_length
#      33 if delta < 0:
#
# Cell In[5], line 6, in tour_length(tour, dist)
#       4 def tour_length(tour, dist ):
#       5     n = len(tour)
# ----> 6     return sum(dist[tour[i]][tour[(i + 1) % n]] for i in range(n))
#
# Cell In[5], line 6, in <genexpr>(.0)
#       4 def tour_length(tour, dist ):
#       5     n = len(tour)
# ----> 6     return sum(dist[tour[i]][tour[(i + 1) % n]] for i in range(n))
#
# KeyboardInterrupt:
